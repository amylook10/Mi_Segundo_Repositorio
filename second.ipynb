# %% [markdown]
# ### Segunda practica en Python
# - **Tema**: Operadores y tipos basicos
# - **Fecha**: 20/12/24

# %%
b = (3*2)+5
print(b)
# Out:
# 11

# %%
c = (3*2+5)
print(c)
# Out:
# 11

# %%
d = 7//2
print(d)
# Out:
# 3

# %%
e = 7%2
print(e)
# Out:
# 1

# %%
f = 2**8
print(f)
# Out:
# 256

# %%
type(f)
# Out:
# int

# %%
b == c
# Out:
# True

# %%
x = 3
x = x+2
print(x)
# Out:
# 5

# %%
x = 3
x += 2 #esto es equivalente a x = x+2
x
# Out:
# 5

# %%
print(y :=2)
# Out:
# 2
